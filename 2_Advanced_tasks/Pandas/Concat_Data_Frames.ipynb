# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# 1. Concatenate two DataFrames to analyze job postings for Data Scientists and Data Analysts:
# Create one DataFrame with job postings for Data Scientists named data_scientist_df and another for Data Analysts named data_analyst_df.
# Concatenate them and display the combined DataFrame called combined_df.

data_scientist_df = df[df['job_title_short'] == 'Data Scientist']
data_analyst_df = df[df['job_title_short'] == 'Data Analyst']

combined_df = pd.concat([data_scientist_df, data_analyst_df], ignore_index=True)
combined_df.head()

combined_df.sample(10)
# Out:
#        job_title_short                                     job_title  \
# 343906    Data Analyst                       Teradata Operations DBA
# 56579   Data Scientist                Intern Data Scientist Photobox
# 298424    Data Analyst           Ref - 365 - Data Analyst Apprentice
# 97315   Data Scientist           Internship - Data Scientist - ML/AI
# 240882    Data Analyst                        Junior Data Analyst:in
# 353370    Data Analyst                      Data Steward and Analyst
# 285990    Data Analyst  Data Analyst Fleet Performance & Engineering
# 349239    Data Analyst             Administrative Data Analyst-ObGyn
# 39486   Data Scientist              Assistant Director, Data Science
# 35690   Data Scientist                             AI Data Scientist
#
#                        job_location            job_via  \
# 343906  Hyderabad, Telangana, India       via LinkedIn
# 56579           Zürich, Switzerland  via BeBee Schweiz
# 298424                     York, UK         via Indeed
# 97315                Wilmington, NC          via BeBee
# 240882              Berlin, Germany          via BeBee
# 353370                        India    via Trabajo.org
# 285990                        India       via LinkedIn
# 349239              Los Angeles, CA    via Trabajo.org
# 39486                      Anywhere         via Indeed
# 35690                   Netherlands          via BeBee
#
#                job_schedule_type  job_work_from_home  \
# 343906                 Full-time               False
# 56579                 Internship               False
# 298424                 Full-time               False
# 97315   Full-time and Internship               False
# 240882                 Full-time               False
# 353370                 Full-time               False
# 285990                 Full-time               False
# 349239                 Full-time               False
# 39486                  Full-time                True
# 35690                  Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 343906                      India 2023-04-09 10:23:30                  False
# 56579                 Switzerland 2023-04-05 07:25:53                  False
# 298424             United Kingdom 2023-02-02 11:14:33                  False
# 97315      Florida, United States 2023-10-11 16:05:04                  False
# 240882                    Germany 2023-12-06 07:15:07                   True
# 353370                      India 2023-07-21 21:12:14                  False
# 285990                      India 2023-04-25 14:12:13                  False
# 349239  California, United States 2023-01-27 02:01:44                  False
# 39486     New York, United States 2023-10-16 15:23:17                  False
# 35690                 Netherlands 2023-10-26 15:48:59                  False
#
#         job_health_insurance     job_country salary_rate  salary_year_avg  \
# 343906                 False           India        None              NaN
# 56579                  False     Switzerland        None              NaN
# 298424                 False  United Kingdom        None              NaN
# 97315                  False   United States        None              NaN
# 240882                 False         Germany        None              NaN
# 353370                 False           India        None              NaN
# 285990                 False           India        None              NaN
# 349239                 False   United States        None              NaN
# 39486                   True   United States        year         147500.0
# 35690                  False     Netherlands        None              NaN
#
#         salary_hour_avg                    company_name  \
# 343906              NaN                        Teradata
# 56579               NaN                  Beyond Gravity
# 298424              NaN                  Estio Training
# 97315               NaN                  Analog Devices
# 240882              NaN               Smart Pricer GmbH
# 353370              NaN  CNS Cloud and Network Services
# 285990              NaN                  Siemens Gamesa
# 349239              NaN                     UCLA Health
# 39486               NaN                  Liberty Mutual
# 35690               NaN                          Sogeti
#
#                                                job_skills  \
# 343906  ['shell', 'sql', 'python', 'sas', 'sas', 'unix...
# 56579                       ['python', 'opencv', 'spark']
# 298424                    ['sql', 'python', 'r', 'excel']
# 97315     ['python', 'go', 'pandas', 'pytorch', 'github']
# 240882              ['python', 'pandas', 'numpy', 'qlik']
# 353370                         ['sql', 'power bi', 'sap']
# 285990                                ['power bi', 'sap']
# 349239        ['sql', 'mysql', 'oracle', 'word', 'excel']
# 39486                                     ['python', 'r']
# 35690                                                None
#
#                                           job_type_skills
# 343906  {'analyst_tools': ['sas', 'microstrategy', 'ta...
# 56579   {'libraries': ['opencv', 'spark'], 'programmin...
# 298424  {'analyst_tools': ['excel'], 'programming': ['...
# 97315   {'libraries': ['pandas', 'pytorch'], 'other': ...
# 240882  {'analyst_tools': ['qlik'], 'libraries': ['pan...
# 353370  {'analyst_tools': ['power bi', 'sap'], 'progra...
# 285990             {'analyst_tools': ['power bi', 'sap']}
# 349239  {'analyst_tools': ['word', 'excel'], 'cloud': ...
# 39486                    {'programming': ['python', 'r']}
# 35690                                                None

# %%
# 2. Concatenate DataFrames to analyze job postings by month:
# Create DataFrames for job postings for the last quarter (October, November, and December). These are respectively called oct_df, nov_df, and dec_df.
# Concatenate them and display the combined DataFrame named combined_df.


oct_df = df[df['job_posted_date'].dt.month == 10]
nov_df = df[df['job_posted_date'].dt.month == 11]
dec_df = df[df['job_posted_date'].dt.month == 12]
combined_df = pd.concat([oct_df, nov_df, dec_df], ignore_index=True)
combined_df
# Out:
#          job_title_short                                          job_title  \
# 0          Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 1          Data Engineer                                      Data Engineer
# 2           Data Analyst                                       Data Analyst
# 3           Data Analyst                           Stage - Data Analyst F/H
# 4           Data Analyst  Data Analyst (Bangkok Based, relocation provided)
# ...                  ...                                                ...
# 187359     Data Engineer                                      Data Engineer
# 187360     Data Engineer                                      Data Engineer
# 187361      Data Analyst                                  Data Analyst Lead
# 187362  Business Analyst         Business Analysis and Intelligence Manager
# 187363    Cloud Engineer                             Engineer 3, Facilities
#
#                                              job_location  \
# 0                                         Berlin, Germany
# 1                                            Aberdeen, UK
# 2                                          Warsaw, Poland
# 3                                           Paris, France
# 4          Rome, Metropolitan City of Rome Capital, Italy
# ...                                                   ...
# 187359                          Ho Chi Minh City, Vietnam
# 187360                                 Gothenburg, Sweden
# 187361                                           Thailand
# 187362  Kuala Lumpur, Federal Territory of Kuala Lumpu...
# 187363                                   Penang, Malaysia
#
#                           job_via         job_schedule_type  \
# 0                    via LinkedIn                 Full-time
# 1                    via LinkedIn                 Temp work
# 2           via Praca Trabajo.org                 Full-time
# 3                    via LinkedIn  Full-time and Internship
# 4                    via LinkedIn                 Full-time
# ...                           ...                       ...
# 187359            via Trabajo.org                 Full-time
# 187360            via Trabajo.org                 Full-time
# 187361            via Trabajo.org                 Full-time
# 187362            via Trabajo.org                 Full-time
# 187363  via Smart Recruiters Jobs                 Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# 0                    False         Germany 2023-10-10 13:14:55
# 1                    False  United Kingdom 2023-10-19 13:37:16
# 2                    False          Poland 2023-10-16 13:36:54
# 3                    False          France 2023-10-19 13:59:31
# 4                    False           Italy 2023-10-30 13:13:21
# ...                    ...             ...                 ...
# 187359               False         Vietnam 2023-12-17 06:23:18
# 187360               False          Sweden 2023-12-13 06:49:09
# 187361               False        Thailand 2023-12-17 06:16:04
# 187362               False        Malaysia 2023-12-05 06:22:35
# 187363               False        Malaysia 2023-12-21 06:12:22
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 0                       False                 False         Germany
# 1                       False                 False  United Kingdom
# 2                       False                 False          Poland
# 3                       False                 False          France
# 4                       False                 False           Italy
# ...                       ...                   ...             ...
# 187359                  False                 False         Vietnam
# 187360                  False                 False          Sweden
# 187361                  False                 False        Thailand
# 187362                  False                 False        Malaysia
# 187363                  False                 False        Malaysia
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 0             None              NaN              NaN
# 1             None              NaN              NaN
# 2             None              NaN              NaN
# 3             None              NaN              NaN
# 4             None              NaN              NaN
# ...            ...              ...              ...
# 187359        None              NaN              NaN
# 187360        None              NaN              NaN
# 187361        None              NaN              NaN
# 187362        None              NaN              NaN
# 187363        None              NaN              NaN
#
#                                              company_name  \
# 0                                ALPHA Augmented Services
# 1                                             Orion Group
# 2                                                   Glovo
# 3       GROUPE BON MARCHÉ : Le Bon Marché Rive Gauche ...
# 4                                                   Agoda
# ...                                                   ...
# 187359                                              Fram^
# 187360                                          Avigna AB
# 187361                               Siam Piwat Co., Ltd.
# 187362                                 Denave (M) Sdn Bhd
# 187363                                    Western Digital
#
#                                                job_skills  \
# 0       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 1                           ['python', 'sql', 'power bi']
# 2       ['sql', 'python', 'r', 'redshift', 'pandas', '...
# 3                                                 ['sql']
# 4       ['sas', 'sas', 'r', 'python', 'vba', 'sql', 'j...
# ...                                                   ...
# 187359  ['sql', 'nosql', 'postgresql', 'mysql', 'spark...
# 187360                                               None
# 187361  ['sql', 'python', 'pyspark', 'excel', 'spreads...
# 187362  ['sql', 'sql server', 'excel', 'word', 'power ...
# 187363                                               None
#
#                                           job_type_skills
# 0       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 1       {'analyst_tools': ['power bi'], 'programming':...
# 2       {'analyst_tools': ['excel', 'looker', 'tableau...
# 3                                {'programming': ['sql']}
# 4       {'analyst_tools': ['sas', 'spss', 'tableau', '...
# ...                                                   ...
# 187359  {'databases': ['postgresql', 'mysql'], 'librar...
# 187360                                               None
# 187361  {'analyst_tools': ['excel', 'spreadsheet'], 'l...
# 187362  {'analyst_tools': ['excel', 'word', 'power bi'...
# 187363                                               None
#
# [187364 rows x 17 columns]

# %%
# 3. Concatenate DataFrames to analyze job postings for different job types:
# Create DataFrames for 'Full-time' roles (called full_time_df) and 'Part-time' roles (called part_time_df) job postings.
# Concatenate them and display the combined DataFrame named combined_df.

full_time_df = df[df['job_schedule_type'] == 'Full-time']
part_time_df = df[df['job_schedule_type'] == 'Part-time']
combined_df = pd.concat([full_time_df, part_time_df], ignore_index=True)
combined_df.sample(5)
# Out:
#           job_title_short                                          job_title  \
# 141567      Data Engineer                      2023 Data Engineer Internship
# 228312  Software Engineer                           Senior Software Engineer
# 247881     Data Scientist                                     Data Scientist
# 706974       Data Analyst  Assistenz oder Junior Data Analyst / Financial...
# 652725       Data Analyst                                       Data analyst
#
#                      job_location  \
# 141567                 Luxembourg
# 228312  Mexico City, CDMX, Mexico
# 247881            Roubaix, France
# 706974         Frankfurt, Germany
# 652725              Paris, France
#
#                                               job_via job_schedule_type  \
# 141567                        via Emplois Trabajo.org         Full-time
# 228312  via Trabajo.org - Vacantes De Empleo, Trabajo         Full-time
# 247881                                   via LinkedIn         Full-time
# 706974                                     via Indeed         Part-time
# 652725                        via Emplois Trabajo.org         Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# 141567               False      Luxembourg 2023-03-19 09:00:04
# 228312               False          Mexico 2023-08-13 07:17:40
# 247881               False          France 2023-02-10 07:55:08
# 706974               False         Germany 2023-11-22 11:21:37
# 652725               False          France 2023-06-28 22:10:38
#
#         job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 141567                  False                 False  Luxembourg        None
# 228312                  False                 False      Mexico        None
# 247881                  False                 False      France        None
# 706974                   True                 False     Germany        None
# 652725                  False                 False      France        None
#
#         salary_year_avg  salary_hour_avg             company_name  \
# 141567              NaN              NaN                   Amazon
# 228312              NaN              NaN                NielsenIQ
# 247881              NaN              NaN             Groupe IRCEM
# 706974              NaN              NaN  FormMed HealthCare GmbH
# 652725              NaN              NaN                   Accile
#
#                                                job_skills  \
# 141567  ['nosql', 'sql', 'scala', 'python', 'aws', 'ha...
# 228312  ['bash', 'python', 'groovy', 'java', 'sql', 'g...
# 247881                                  ['python', 'sql']
# 706974                              ['excel', 'power bi']
# 652725                                 ['sql', 'tableau']
#
#                                           job_type_skills
# 141567  {'analyst_tools': ['tableau'], 'cloud': ['aws'...
# 228312  {'cloud': ['azure', 'aws'], 'os': ['linux', 'w...
# 247881                 {'programming': ['python', 'sql']}
# 706974           {'analyst_tools': ['excel', 'power bi']}
# 652725  {'analyst_tools': ['tableau'], 'programming': ...
