# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# 1. Create a DataFrame df_us_jobs that contains only job postings in the United States.
# Then, create another DataFrame df_monthly_postings that counts the number of U.S. job postings for each month.
# Merge these two DataFrames on the job_posted_month column using a right join, and display the first 5 rows of the resulting DataFrame.

df['job_posted_month'] = df['job_posted_date'].dt.strftime('%B')
df_us_jobs = df[df['job_country'] == 'United States']
df_monthly_postings = df_us_jobs.groupby('job_posted_month').size().reset_index(name='postings_count')
merged_df = pd.merge(df_us_jobs, df_monthly_postings, on='job_posted_month', how='right')
merged_df.head()
# Out:
#          job_title_short                                          job_title  \
# 0         Data Scientist                                  Data Scientist II
# 1         Data Scientist        Data Scientist, Data Strategy and Analytics
# 2  Senior Data Scientist  Mission Data Scientist, Senior - Security Clea...
# 3          Data Engineer                                      Data Engineer
# 4           Data Analyst                           HR Data Analyst - Remote
#
#        job_location                job_via job_schedule_type  \
# 0          Anywhere       via ZipRecruiter         Full-time
# 1       Alameda, CA        via Trabajo.org         Full-time
# 2  Fayetteville, NC  via My Panhandle Jobs         Full-time
# 3     Las Vegas, NV        via Trabajo.org         Full-time
# 4          Anywhere       via ZipRecruiter         Full-time
#
#    job_work_from_home            search_location     job_posted_date  \
# 0                True    New York, United States 2023-04-23 13:02:57
# 1               False  California, United States 2023-04-26 13:05:10
# 2               False                    Georgia 2023-04-09 14:21:49
# 3               False    Illinois, United States 2023-04-28 13:09:58
# 4                True  California, United States 2023-04-24 13:00:47
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False  United States        None
# 2                  False                  True  United States        None
# 3                   True                 False  United States        None
# 4                  False                 False  United States        None
#
#    salary_year_avg  salary_hour_avg                          company_name  \
# 0              NaN              NaN            Radwell International, LLC
# 1              NaN              NaN                                Abbott
# 2              NaN              NaN                   Booz Allen Hamilton
# 3              NaN              NaN  Indotronix International Corporation
# 4              NaN              NaN                   Workoo Technologies
#
#                                           job_skills  \
# 0  ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# 1                                               None
# 2  ['python', 'r', 'postgresql', 'pandas', 'table...
# 3  ['python', 'shell', 'azure', 'databricks', 'ai...
# 4                              ['sas', 'sas', 'sql']
#
#                                      job_type_skills job_posted_month  \
# 0  {'analyst_tools': ['excel'], 'cloud': ['azure'...            April
# 1                                               None            April
# 2  {'analyst_tools': ['tableau', 'splunk'], 'data...            April
# 3  {'cloud': ['azure', 'databricks'], 'libraries'...            April
# 4  {'analyst_tools': ['sas'], 'programming': ['sa...            April
#
#    postings_count
# 0           17282
# 1           17282
# 2           17282
# 3           17282
# 4           17282

# %%
# 2. Create a DataFrame df_not_remote_jobs that contains only job postings that do not offer remote work (job_work_from_home == False).
# From df_not_remote_jobs, calculate the average yearly salary (salary_year_avg) for each job title (job_title_short).Store the result in a new DataFrame df_not_remote_salary.Rename the salary column to salary_not_remote_avg.
# Merge df_not_remote_jobs and df_not_remote_salary on the job_title_short column using a right join.
# Display the first 5 rows of the resulting DataFrame.

df_not_remote_jobs = df[df['job_work_from_home'] == False]

df_not_remote_salary = (
    df_not_remote_jobs
    .groupby('job_title_short')['salary_year_avg']
    .mean()
    .reset_index()
    .rename(columns={'salary_year_avg': 'salary_not_remote_avg'})
)

merged_df = df_not_remote_jobs.merge(df_not_remote_salary, on = 'job_title_short', how='right')
merged_df.head()
# Out:
#     job_title_short                                 job_title  \
# 0  Business Analyst  Technology & Operations Business Analyst
# 1  Business Analyst              Business Intelligence Intern
# 2  Business Analyst                               BI Engineer
# 3  Business Analyst                          Business Analyst
# 4  Business Analyst                        Commercial Analyst
#
#             job_location             job_via job_schedule_type  \
# 0    Copenhagen, Denmark     via Trabajo.org         Full-time
# 1             Dallas, TX        via LinkedIn         Full-time
# 2                Namibia  via Intellijobs.ai         Full-time
# 3  Tel Aviv-Yafo, Israel          via Comeet         Full-time
# 4           South Africa        via LinkedIn         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False               Denmark 2023-06-05 13:44:34
# 1               False  Texas, United States 2023-01-04 13:02:07
# 2               False               Namibia 2023-03-05 14:10:49
# 3               False                Israel 2023-09-05 13:50:12
# 4               False          South Africa 2023-02-14 13:36:23
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False        Denmark        None
# 1                  False                 False  United States        None
# 2                  False                 False        Namibia        None
# 3                  False                 False         Israel        None
# 4                   True                 False   South Africa        None
#
#    salary_year_avg  salary_hour_avg company_name  \
# 0              NaN              NaN       Hempel
# 1              NaN              NaN       Copart
# 2              NaN              NaN      Innover
# 3              NaN              NaN   ironSource
# 4              NaN              NaN          PEP
#
#                                       job_skills  \
# 0            ['excel', 'powerpoint', 'power bi']
# 1  ['r', 'python', 'sql', 'tableau', 'power bi']
# 2            ['sql', 'gcp', 'looker', 'tableau']
# 3                               ['sql', 'excel']
# 4              ['sql', 'tableau', 'spss', 'sap']
#
#                                      job_type_skills job_posted_month  \
# 0  {'analyst_tools': ['excel', 'powerpoint', 'pow...             June
# 1  {'analyst_tools': ['tableau', 'power bi'], 'pr...          January
# 2  {'analyst_tools': ['looker', 'tableau'], 'clou...            March
# 3  {'analyst_tools': ['excel'], 'programming': ['...        September
# 4  {'analyst_tools': ['tableau', 'spss', 'sap'], ...         February
#
#    salary_not_remote_avg
# 0            90177.41994
# 1            90177.41994
# 2            90177.41994
# 3            90177.41994
# 4            90177.41994

# %%
# 3. Create a DataFrame df_company_salary that calculates the average yearly salary for each company.
# Then, create another DataFrame df_company_remote that counts the number of remote job postings for each company. Name this count column remote_count.
# Merge these two DataFrames on the company_name column using an inner join and display the first 5 rows of the resulting DataFrame.


df_company_salary = (
    df.groupby('company_name')['salary_year_avg']
    .mean()
    .reset_index()
    )

df_company_remote = (
    df[df['job_work_from_home'] == True]
    .groupby('company_name')
    .size()
    .reset_index(name='remote_count')
    )

merged_df = df_company_remote.merge(df_company_salary, on = 'company_name', how = 'inner')
merged_df.head()
# Out:
#                                 company_name  remote_count  salary_year_avg
# 0                                #EqualsTrue             4              NaN
# 1                              #TeamGoHealth             1              NaN
# 2                    #twiceasnice Recruiting             1          77750.0
# 3                                      &Work             1              NaN
# 4  (AEG) Application Engineering Group, Inc.             1              NaN
